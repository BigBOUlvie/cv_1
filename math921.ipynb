# %%
import cv2
from ultralytics import YOLO
import numpy as np
import os
from collections import defaultdict
import torch
import torchvision
from collections import deque
import pandas as pd
os.environ['KMP_DUPLICATE_LIB_OK']='True'
#设置模型
model = YOLO("yolov8n.pt")

# %%
#读取视频
cap = cv2.VideoCapture("clip_1.mp4")
current_positions = {}
speeds = []
video_length_meters = 720  # 视频高度覆盖的真实长度，单位：米
video_resolution_height = 384 
conversion_factor = video_length_meters / video_resolution_height
# 视频高度的像素数
fps = 25 # 视频的fps
time_interval = 1 / fps #视频中一帧的现实时间差
frame_number = 0 #初始化帧数
prev_positions = {}  
centers = []
window_size = 25 
vehicle_window = deque(maxlen=window_size)
columns = ['Frame Number', 'Flow (vehicles/s)', 'Density (vehicles/m)']  # 初始列
df = pd.DataFrame(columns=columns)

# %%
def calculate_instantaneous_speed(current_position, previous_position, time_elapsed, center_y):
    if time_elapsed <= 0:  # 避免时间间隔为 0 或负数
        return 0
    # 计算两帧之间的像素距离
    pixel_distance = np.sqrt(
        (current_position[0] - previous_position[0]) ** 2 + (current_position[1] - previous_position[1]) ** 2)
    actual_distance = pixel_distance * conversion_factor
    max_y = video_resolution_height  
    # 当车辆在图像底部（靠近摄像头）时，进一步减小速度
    if center_y > max_y * 0.75:  # 车辆非常接近摄像头
        adjustment_factor = 70  # 增加缩放因子，减小速度
    elif center_y > max_y * 0.5:  # 车辆中等接近
        adjustment_factor = 30
    else:
        adjustment_factor = 5 + (max_y - center_y) / max_y * 15
    # 计算调整后的速度
    adjusted_speed = (actual_distance / time_elapsed) / adjustment_factor
    adjusted_speed = adjusted_speed / 6
    adjusted_speed = max(0, min(adjusted_speed, 36))
    return adjusted_speed

# %%
while True:
    success, frame= cap.read()
    if not success:
        break
    results = model.track(frame,persist=True)
    a = results[0].plot()
    track_ids = results[0].boxes.id.int().cpu().tolist()
    #####
    frame = int(frame_number)
    boxes = results[0].boxes.xywh.cpu() #获取车辆坐标
    current_frame_vehicle_count = len(track_ids)#当前帧的车辆数
    current_ids = set(track_ids)
    vehicle_window.append(current_ids)
    unique_id = set().union(*vehicle_window)#确保车辆id唯一
    flow_rate = len(unique_id) #车辆流量：单位时间内通过的车辆数
    vehicle_density = current_frame_vehicle_count #车辆密度
    print(f"Frame {frame_number}, Flow (last {window_size} frames): {flow_rate} vehicles, Density: {vehicle_density} vehicles")#输出当前帧数，车流量和车密度
    #######
    for box , track_id in zip(boxes,track_ids):
        x,y,w,h = box
        center_x, center_y = x,y #获取检测到的车辆中心点
        center = (float(center_x),float(center_y))
        centers.append(center)
        if track_id in prev_positions:
            prev_frame ,prev_center= prev_positions[track_id] #若检测到的车出现过，获取之前其出现的帧数和位置
            time_elapsed = (frame_number - prev_frame) * (1 / fps) #计算当前检测到的车辆的时间差
            try:
                speed = calculate_instantaneous_speed((float(center_x),float(center_y)),prev_center,time_elapsed,float(center_y)) #计算调整后的车速
            except ValueError:
                speed = 0
        else:
            speed = 0
        speeds.append(speed)
        prev_positions[track_id] = (frame_number,center)#更新车辆出现的帧数和位置

    #####
    row_data = [frame_number, flow_rate, vehicle_density] #保存数据
    for track_id in prev_positions.keys():
        if track_id in current_ids:
            # 如果车辆存在，记录当前速度
            idx = list(track_ids).index(track_id)
            speed1 = speeds[idx]
        else:
            # 如果车辆不在当前帧，将速度设置为0
            speed1 = None

        # 更新车辆位置并写入数据表
        vehicle_column = f'ID{track_id}'
        if vehicle_column not in df.columns:
            df[vehicle_column] = np.nan  # 初始化该列
        # 将速度信息加入数据
        row_data.append(speed1)
    # 确保数据表的列与row_data匹配
    while len(row_data) < len(df.columns):
        row_data.append(np.nan)  # 填充没有数据的列
    # 将数据写入当前帧的行
    df.loc[len(df)] = row_data
    frame_number +=1
    speeds = []
    cv2.imshow("123",a)
    if cv2.waitKey(1)& 0xFF ==ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# 0: 384x640 5 cars, 69.6ms
# Speed: 7.5ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 0, Flow (last 25 frames): 5 vehicles, Density: 5 vehicles
#
# 0: 384x640 5 cars, 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1, Flow (last 25 frames): 5 vehicles, Density: 5 vehicles
#
# 0: 384x640 5 cars, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2, Flow (last 25 frames): 5 vehicles, Density: 5 vehicles
#
# 0: 384x640 6 cars, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3, Flow (last 25 frames): 6 vehicles, Density: 6 vehicles
#
# 0: 384x640 8 cars, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4, Flow (last 25 frames): 8 vehicles, Density: 8 vehicles
#
# 0: 384x640 8 cars, 29.0ms
# Speed: 1.6ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5, Flow (last 25 frames): 8 vehicles, Density: 8 vehicles
#
# 0: 384x640 8 cars, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6, Flow (last 25 frames): 9 vehicles, Density: 8 vehicles
#
# 0: 384x640 7 cars, 1 truck, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7, Flow (last 25 frames): 9 vehicles, Density: 8 vehicles
#
# 0: 384x640 7 cars, 1 truck, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8, Flow (last 25 frames): 9 vehicles, Density: 8 vehicles
#
# 0: 384x640 7 cars, 1 truck, 36.2ms
# Speed: 2.0ms preprocess, 36.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9, Flow (last 25 frames): 9 vehicles, Density: 8 vehicles
#
# 0: 384x640 8 cars, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10, Flow (last 25 frames): 9 vehicles, Density: 8 vehicles
#
# 0: 384x640 9 cars, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11, Flow (last 25 frames): 10 vehicles, Density: 9 vehicles
#
# 0: 384x640 8 cars, 1 truck, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12, Flow (last 25 frames): 10 vehicles, Density: 9 vehicles
#
# 0: 384x640 9 cars, 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13, Flow (last 25 frames): 10 vehicles, Density: 9 vehicles
#
# 0: 384x640 10 cars, 30.3ms
# Speed: 2.0ms preprocess, 30.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14, Flow (last 25 frames): 11 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15, Flow (last 25 frames): 11 vehicles, Density: 10 vehicles
#
# 0: 384x640 11 cars, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16, Flow (last 25 frames): 12 vehicles, Density: 11 vehicles
#
# 0: 384x640 13 cars, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17, Flow (last 25 frames): 14 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 31.8ms
# Speed: 1.0ms preprocess, 31.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18, Flow (last 25 frames): 14 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19, Flow (last 25 frames): 14 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20, Flow (last 25 frames): 14 vehicles, Density: 12 vehicles
#
# 0: 384x640 11 cars, 37.6ms
# Speed: 1.9ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21, Flow (last 25 frames): 14 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22, Flow (last 25 frames): 14 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23, Flow (last 25 frames): 14 vehicles, Density: 11 vehicles
#
# 0: 384x640 12 cars, 35.1ms
# Speed: 2.6ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24, Flow (last 25 frames): 15 vehicles, Density: 12 vehicles
#
# 0: 384x640 13 cars, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25, Flow (last 25 frames): 16 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26, Flow (last 25 frames): 16 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27, Flow (last 25 frames): 16 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28, Flow (last 25 frames): 16 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 1 truck, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29, Flow (last 25 frames): 16 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 1 truck, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30, Flow (last 25 frames): 15 vehicles, Density: 13 vehicles
#
# 0: 384x640 13 cars, 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31, Flow (last 25 frames): 15 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 1 truck, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32, Flow (last 25 frames): 15 vehicles, Density: 13 vehicles
#
# 0: 384x640 14 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33, Flow (last 25 frames): 17 vehicles, Density: 14 vehicles
#
# 0: 384x640 13 cars, 31.7ms
# Speed: 1.0ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34, Flow (last 25 frames): 17 vehicles, Density: 13 vehicles
#
# 0: 384x640 14 cars, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35, Flow (last 25 frames): 18 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36, Flow (last 25 frames): 18 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37, Flow (last 25 frames): 18 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38, Flow (last 25 frames): 18 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39, Flow (last 25 frames): 18 vehicles, Density: 14 vehicles
#
# 0: 384x640 15 cars, 1 truck, 36.8ms
# Speed: 1.9ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40, Flow (last 25 frames): 20 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41, Flow (last 25 frames): 20 vehicles, Density: 16 vehicles
#
# 0: 384x640 14 cars, 36.4ms
# Speed: 2.0ms preprocess, 36.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42, Flow (last 25 frames): 20 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 1 truck, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43, Flow (last 25 frames): 21 vehicles, Density: 15 vehicles
#
# 0: 384x640 15 cars, 33.2ms
# Speed: 1.1ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44, Flow (last 25 frames): 20 vehicles, Density: 15 vehicles
#
# 0: 384x640 14 cars, 1 truck, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45, Flow (last 25 frames): 19 vehicles, Density: 15 vehicles
#
# 0: 384x640 15 cars, 30.6ms
# Speed: 2.0ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46, Flow (last 25 frames): 19 vehicles, Density: 15 vehicles
#
# 0: 384x640 16 cars, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47, Flow (last 25 frames): 20 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48, Flow (last 25 frames): 20 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 31.5ms
# Speed: 1.0ms preprocess, 31.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49, Flow (last 25 frames): 20 vehicles, Density: 16 vehicles
#
# 0: 384x640 15 cars, 38.5ms
# Speed: 2.5ms preprocess, 38.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50, Flow (last 25 frames): 20 vehicles, Density: 15 vehicles
#
# 0: 384x640 16 cars, 53.0ms
# Speed: 2.9ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51, Flow (last 25 frames): 21 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52, Flow (last 25 frames): 21 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53, Flow (last 25 frames): 22 vehicles, Density: 16 vehicles
#
# 0: 384x640 17 cars, 31.8ms
# Speed: 1.3ms preprocess, 31.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54, Flow (last 25 frames): 23 vehicles, Density: 17 vehicles
#
# 0: 384x640 16 cars, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55, Flow (last 25 frames): 23 vehicles, Density: 16 vehicles
#
# 0: 384x640 16 cars, 31.0ms
# Speed: 2.0ms preprocess, 31.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56, Flow (last 25 frames): 23 vehicles, Density: 16 vehicles
#
# 0: 384x640 15 cars, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57, Flow (last 25 frames): 22 vehicles, Density: 15 vehicles
#
# 0: 384x640 14 cars, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58, Flow (last 25 frames): 21 vehicles, Density: 14 vehicles
#
# 0: 384x640 14 cars, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59, Flow (last 25 frames): 21 vehicles, Density: 14 vehicles
#
# 0: 384x640 15 cars, 33.1ms
# Speed: 2.0ms preprocess, 33.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60, Flow (last 25 frames): 22 vehicles, Density: 15 vehicles
#
# 0: 384x640 14 cars, 1 truck, 42.2ms
# Speed: 1.4ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61, Flow (last 25 frames): 23 vehicles, Density: 15 vehicles
#
# 0: 384x640 14 cars, 1 truck, 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62, Flow (last 25 frames): 23 vehicles, Density: 15 vehicles
#
# 0: 384x640 15 cars, 1 truck, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63, Flow (last 25 frames): 24 vehicles, Density: 16 vehicles
#
# 0: 384x640 14 cars, 1 truck, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64, Flow (last 25 frames): 24 vehicles, Density: 15 vehicles
#
# 0: 384x640 14 cars, 1 truck, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65, Flow (last 25 frames): 24 vehicles, Density: 15 vehicles
#
# 0: 384x640 13 cars, 1 truck, 38.4ms
# Speed: 2.1ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66, Flow (last 25 frames): 22 vehicles, Density: 14 vehicles
#
# 0: 384x640 13 cars, 1 truck, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67, Flow (last 25 frames): 22 vehicles, Density: 14 vehicles
#
# 0: 384x640 13 cars, 1 truck, 34.3ms
# Speed: 2.0ms preprocess, 34.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68, Flow (last 25 frames): 22 vehicles, Density: 14 vehicles
#
# 0: 384x640 13 cars, 1 truck, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69, Flow (last 25 frames): 22 vehicles, Density: 14 vehicles
#
# 0: 384x640 13 cars, 1 truck, 34.6ms
# Speed: 1.9ms preprocess, 34.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70, Flow (last 25 frames): 22 vehicles, Density: 14 vehicles
#
# 0: 384x640 12 cars, 1 truck, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71, Flow (last 25 frames): 22 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 1 truck, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72, Flow (last 25 frames): 22 vehicles, Density: 13 vehicles
#
# 0: 384x640 12 cars, 1 truck, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73, Flow (last 25 frames): 22 vehicles, Density: 13 vehicles
#
# 0: 384x640 11 cars, 34.2ms
# Speed: 2.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74, Flow (last 25 frames): 22 vehicles, Density: 11 vehicles
#
# 0: 384x640 10 cars, 35.1ms
# Speed: 2.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75, Flow (last 25 frames): 23 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 1 truck, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76, Flow (last 25 frames): 23 vehicles, Density: 11 vehicles
#
# 0: 384x640 10 cars, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77, Flow (last 25 frames): 22 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78, Flow (last 25 frames): 22 vehicles, Density: 10 vehicles
#
# 0: 384x640 11 cars, 32.7ms
# Speed: 2.2ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Frame 81, Flow (last 25 frames): 20 vehicles, Density: 11 vehicles
#
# 0: 384x640 12 cars, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 82, Flow (last 25 frames): 20 vehicles, Density: 12 vehicles
#
# 0: 384x640 11 cars, 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 83, Flow (last 25 frames): 20 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 43.0ms
# Speed: 1.7ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 84, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 12 cars, 36.7ms
# Speed: 2.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 85, Flow (last 25 frames): 21 vehicles, Density: 12 vehicles
#
# 0: 384x640 11 cars, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 86, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 11 cars, 1 truck, 39.3ms
# Speed: 1.9ms preprocess, 39.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 87, Flow (last 25 frames): 22 vehicles, Density: 12 vehicles
#
# 0: 384x640 11 cars, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 88, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 10 cars, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 89, Flow (last 25 frames): 21 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 53.3ms
# Speed: 1.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 90, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 91, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles
#
# 0: 384x640 9 cars, 1 truck, 36.3ms
# Speed: 2.0ms preprocess, 36.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 92, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 93, Flow (last 25 frames): 21 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 37.0ms
# Speed: 2.0ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 94, Flow (last 25 frames): 21 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 43.4ms
# Speed: 0.6ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 95, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles
#
# 0: 384x640 11 cars, 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 96, Flow (last 25 frames): 21 vehicles, Density: 11 vehicles
#
# 0: 384x640 10 cars, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 97, Flow (last 25 frames): 21 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 37.9ms
# Speed: 2.0ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 98, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles
#
# 0: 384x640 10 cars, 37.3ms
# Speed: 1.0ms preprocess, 37.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 99, Flow (last 25 frames): 19 vehicles, Density: 10 vehicles
#
# 0: 384x640 11 cars, 44.7ms
# Speed: 2.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 100, Flow (last 25 frames): 19 vehicles, Density: 11 vehicles
#
# 0: 384x640 12 cars, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 101, Flow (last 25 frames): 20 vehicles, Density: 12 vehicles
#
# 0: 384x640 12 cars, 33.3ms
# Speed: 2.6ms preprocess, 33.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 102, Flow (last 25 frames): 20 vehicles, Density: 12 vehicles
#
# 0: 384x640 10 cars, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 103, Flow (last 25 frames): 20 vehicles, Density: 10 vehicles

# %%
df.to_excel('a103.xlsx')#导出数据
